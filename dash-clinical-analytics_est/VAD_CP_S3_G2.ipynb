# %%
import dash
from dash import dcc, html, Input, Output, callback, ctx
import plotly.express as px
import numpy as np
import pandas as pd
import datetime
import json
from datetime import datetime as dt
import pathlib
import plotly.graph_objects as go 
import plotly.io as pio
import dash_bootstrap_components as dbc

# %%
def preprocesamiento(df):
    # Llenar las categorias vacias con 'No Identificado'
    df["Admit Source"] = df["Admit Source"].fillna("Not Identified")
    # Date
    # Formateo "checkin Time"
    df["Check-In Time"] = df["Check-In Time"].apply(
        lambda x: dt.strptime(x, "%Y-%m-%d %I:%M:%S %p")
    )  # String -> Datetime

    # Insertar día de la semana y hora del "Checking time"
    df["Days of Wk"] = df["Check-In Hour"] = df["Check-In Time"]
    df["Days of Wk"] = df["Days of Wk"].apply(
        lambda x: dt.strftime(x, "%A")
    )  # Datetime -> weekday string

    df["Check-In Hour"] = df["Check-In Hour"].apply(
        lambda x: dt.strftime(x, "%I %p")
    )  # Datetime -> int(hour) + AM/PM

    return df

# %%
# Leer los datos y limpiarlos
df = pd.read_csv("../dash-clinical-analytics_est/data/clinical_analytics.csv")
# realizar preprocesamiento de fecha
df = preprocesamiento(df)

# %%
df.head()
# Out:
#      Admit Source Admit Type         Appt Start Time  Care Score  \
# 0  Emergency Room  Emergency  2014-01-02 11:38:50 PM           2
# 1  Emergency Room  Emergency  2014-01-02 11:44:18 PM           2
# 2  Emergency Room  Emergency  2014-01-02 11:47:11 PM           2
# 3  Emergency Room  Emergency  2014-01-08 10:38:04 PM           4
# 4  Emergency Room  Emergency  2014-01-09 12:00:26 AM           4
#
#         Check-In Time     Clinic Name  Department Diagnosis Primary  \
# 0 2014-01-02 23:24:00  Madison Center  Cardiology               NaN
# 1 2014-01-02 23:24:00  Madison Center  Cardiology               NaN
# 2 2014-01-02 23:24:00  Madison Center  Cardiology               NaN
# 3 2014-01-08 21:00:00  Madison Center   Emergency               NaN
# 4 2014-01-08 22:47:00  Madison Center   Emergency               NaN
#
#   Discharge Datetime new Encounter Number Encounter Status  Number of Records  \
# 0                    NaN        P7P4KC587        Cancelled                  1
# 1                    NaN        P7P4KC587        Cancelled                  1
# 2                    NaN        P7P4KC587        Cancelled                  1
# 3                    NaN        PK559C587        Cancelled                  1
# 4                    NaN        48559C587        Cancelled                  1
#
#    Wait Time Min Days of Wk Check-In Hour
# 0             14   Thursday         11 PM
# 1             20   Thursday         11 PM
# 2             23   Thursday         11 PM
# 3             98  Wednesday         09 PM
# 4             73  Wednesday         10 PM

# %%
clinicas = df["Clinic Name"].unique()
sources = df["Admit Source"].unique()
df_filtrado = df.groupby(["Clinic Name", "Days of Wk", "Check-In Hour"]).sum("Numberof Records").reset_index()

# %% [markdown]
# # Fase 1
#
# En esta fase se debe realizar una planificación de cómo se construirá el tablero.
# Para lo cual deben dar respuesta a los siguientes cuestionamientos:
#
# **1. Como estructuraran el Dashboard?**
#
# RT: El diagrama que responde a esta pregunta está en la carpeta anexos con el nombre de "Respuesta_fase_1.png"
#
# **2. ¿Qué componentes y estilos piensan usar y porqué?**
#
# RT: Se pretende utilizar componentes de html, dash y bootstrap embebidos en python como por ejemplo: Headers, tablas, parrafos, contenedores(divs), datepickersrange, Dropdown, graph,
#
# **3. Qué interacciones deben tener estos componentes.**
#
# RT: En primera instancia deben ser interactivos con el usuario, mostrar la información correspondiente y variar de acuerdo a los filtros seleccionados.

# %%
df_new = df_filtrado[(df_filtrado["Days of Wk"] == 'Friday') & (df_filtrado["Check-In Hour"] == '03 AM')]
#df_new = df_new[df_new["Check-In Hour"] == '03 AM']
df_new.head()
# Out:
#          Clinic Name Days of Wk Check-In Hour  Care Score  Number of Records  \
# 4    Lakeview Center     Friday         03 AM          98                 32
# 172   Madison Center     Friday         03 AM         234                 79
# 340   Surgery Center     Friday         03 AM          63                 23
#
#      Wait Time Min
# 4             2178
# 172           5472
# 340           1672

# %% [markdown]
# #Fase 2
#
# En esta fase se procederá con la estructura y la personalización (estilos) del
# dashboard. Recuerden que pueden usar estilos css, personalización a través de
# html o el uso de Bootstrap

# %%
# Estructura App
external_stylesheets = [dbc.themes.CERULEAN]
app = dash.Dash(
    __name__,
    meta_tags=[{"name": "viewport", "content":
                "width=device-width, initial-scale=1"}],
    external_stylesheets=external_stylesheets
)
app.title = "Clinical Analytics Dashboard"

fig_hm = go.Figure(go.Heatmap(
    z=df_filtrado["Number of Records"],
    x=df_filtrado["Check-In Hour"],
    y=df_filtrado["Days of Wk"],
    text=df_filtrado["Number of Records"],
    texttemplate="%{text}"
))

contenedor = dbc.Container([
    dbc.Row([
        html.Div([
            html.H1("Creación de Dashboard", style={'textAlign':'center'}),
            html.H1("Interactivo", style={'textAlign':'center'})
        ], style={'marginBottom': 25, 'marginTop': 25})
    ]),
    dbc.Row([
        dbc.Col([
            html.P("Selecciona la clinica:", className="text-center"),
        ], md= 1),
        dbc.Col([
            dcc.Dropdown(clinicas, id="dropdown_1", persistence= True),
        ], md= 5),
        dbc.Col([
            html.P("Selecciona en rango de fecha:", className="text-center"),
        ], md= 2),
        dbc.Col([
            dcc.DatePickerRange(id="date_1"),
        ], md= 4),
    ]),
    dbc.Row([
        dbc.Col([
            html.P("Selecciona Origen Paciente:", className="text-center"),
        ], md= 2),
        dbc.Col([
            dcc.Dropdown(options=[{'label': s, 'value': s} for s in sources], value=sources[:3], id="dropdown_2", multi=True)
        ], md= 9),
    ]),
    
    dbc.Row([
        dbc.Col([
            html.H3("Mapa de calor", style={'textAlign':'center'}),
            dcc.Graph(id="grafico_hm", figure=fig_hm),
        ])
    ]),
    dbc.Row([
        html.H3("Tiempo de espera", style={'textAlign':'center'}),
        dcc.Graph(id='salida_click'),
    ]),
    dbc.Row([
        html.H3("Calificación", style={'textAlign':'center'}),
        dcc.Graph(id='salida_click_score')
    ])

])

@app.callback(
    Output("grafico_hm", "figure"),  
    [
        Input("dropdown_1", "value"),
        Input("date_1", "start_date"),
        Input("date_1", "end_date"),
        Input("dropdown_2", "value")
    ]
)
def update_graph(value, start_date, end_date, dropdown2):
    entra = 'N'
    triggered_id = ctx.triggered_id

    # Reviso los valores que llaman
    print(value)
    print(dropdown2)
    print(start_date, end_date)

    
    # Si alguno de los filtros cambia, se actualiza el gráfico
    if triggered_id in ["dropdown_1", "dropdown_2", "date_1"]:

        entra ='S'
        # Empiezo a filtrar por los valores que recibe la función
        df_grafico = df.copy()
        
        if value is not None: 
            df_grafico = df_grafico[df_grafico["Clinic Name"] == value]

        if dropdown2 is not None:
            df_grafico = df_grafico[df_grafico["Admit Source"].isin(dropdown2)]

        if start_date is not None and end_date is not None:
            df_grafico = df_grafico[(df_grafico['Appt Start Time'] >= start_date) & (df_grafico['Appt Start Time'] <= end_date)]

        df_agrupado = df_grafico.groupby(["Clinic Name", "Days of Wk", "Check-In Hour"]).sum("Numberof Records").reset_index()

        # Genero el heatmap con los datos filtrados
        fig_hm = go.Figure(go.Heatmap(
            z=df_agrupado["Number of Records"],
            x=df_agrupado["Check-In Hour"],
            y=df_agrupado["Days of Wk"],
            text=df_agrupado["Number of Records"],
            texttemplate="%{text}"
        ))

        # Retorno la figura actualizada
        return fig_hm
    
    if entra != 'S':
        fig_hm = go.Figure(go.Heatmap(
            z=df_filtrado["Number of Records"],
            x=df_filtrado["Check-In Hour"],
            y=df_filtrado["Days of Wk"],
            text=df_filtrado["Number of Records"],
            texttemplate="%{text}"
        ))
    # Si no hay cambios en los filtros, retorno el gráfico original 
    return fig_hm


@app.callback(
    Output("salida_click", "figure"), 
    [Input("grafico_hm", "clickData"),
     Input("dropdown_1", "value")]
)
def salida_click(clickData, clinic_name):
    triggered_id = ctx.triggered_id

    fig=px.box()

    if (triggered_id == "grafico_hm"):

        df_grafico_cajas = df.copy()

        valor_x = clickData["points"][0]["x"]
        valor_y = clickData["points"][0]["y"]
                
        df_grafico_cajas_2 = df_grafico_cajas[(df_grafico_cajas["Days of Wk"] == valor_y) & (df_grafico_cajas["Check-In Hour"] == valor_x)]

        if clinic_name is not None:
            df_grafico_cajas_2 = df_grafico_cajas_2[df_grafico_cajas_2["Clinic Name"] == clinic_name]
            
        print(df_grafico_cajas_2)

        fig = px.box(df_grafico_cajas_2, y="Wait Time Min", facet_col = 'Admit Type')
    
    return fig

@app.callback(
    Output("salida_click_score", "figure"), 
    [Input("grafico_hm", "clickData"),
     Input("dropdown_1", "value")]
)
def salida_click_sc(clickData, clinic_name):
    triggered_id = ctx.triggered_id

    fig=px.box()

    if (triggered_id == "grafico_hm"):

        df_grafico_cajas = df.copy()

        valor_x = clickData["points"][0]["x"]
        valor_y = clickData["points"][0]["y"]
                
        df_grafico_cajas_2 = df_grafico_cajas[(df_grafico_cajas["Days of Wk"] == valor_y) & (df_grafico_cajas["Check-In Hour"] == valor_x)]

        if clinic_name is not None:
            df_grafico_cajas_2 = df_grafico_cajas_2[df_grafico_cajas_2["Clinic Name"] == clinic_name]
            
        print(df_grafico_cajas_2)

        fig = px.box(df_grafico_cajas_2, y="Care Score", facet_col = 'Admit Type')
    
    return fig



app.layout = html.Div(contenedor)


if __name__ == "__main__":
    app.run_server(debug=True, port=5004)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:5004/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Lakeview Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 74898  Inpatient Discharged                  1             51  Wednesday
#
#       Check-In Hour
# 4590          01 AM
# 4591          01 AM
# 4592          01 AM
# 11731         01 AM
# 11732         01 AM
# 19565         01 AM
# 19566         01 AM
# 30820         01 AM
# 30821         01 AM
# 30822         01 AM
# 30823         01 AM
# 33241         01 AM
# 33242         01 AM
# 46390         01 AM
# 46391         01 AM
# 53652         01 AM
# 53653         01 AM
# 56578         01 AM
# 56579         01 AM
# 65884         01 AM
# 65885         01 AM
# 74896         01 AM
# 74897         01 AM
# 74898         01 AM
#
#           Admit Source Admit Type        Appt Start Time  Care Score  \
# 169    Clinic Referral   Elective  2014-04-28 7:14:20 AM           5
# 170    Clinic Referral   Elective  2014-04-28 7:32:29 AM           3
# 438    Clinic Referral   Elective  2014-11-03 6:23:36 AM           3
# 439    Clinic Referral   Elective  2014-11-03 6:33:32 AM           2
# 440    Clinic Referral   Elective  2014-11-03 6:43:28 AM           3
# ...                ...        ...                    ...         ...
# 80541  Clinic Referral   Elective  2014-12-29 8:57:25 AM           2
# 81231  Clinic Referral   Elective  2014-12-29 6:49:10 AM           3
# 81232  Clinic Referral   Elective  2014-12-29 7:02:08 AM           2
# 81233  Clinic Referral   Elective  2014-12-29 7:19:42 AM           2
# 81234  Clinic Referral   Elective  2014-12-29 8:05:12 AM           2
#
#             Check-In Time      Clinic Name      Department  \
# 169   2014-04-28 06:14:00  Lakeview Center  Dental Surgery
# 170   2014-04-28 06:14:00  Lakeview Center  Dental Surgery
# 438   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# 439   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# 440   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# ...                   ...              ...             ...
# 80541 2014-12-29 06:53:00  Lakeview Center  Otolaryngology
# 81231 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81232 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81233 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81234 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
#
#                Diagnosis Primary Discharge Datetime new Encounter Number  \
# 169                          NaN                    NaN        1249P1587
# 170                          NaN                    NaN        1249P1587
# 438                          NaN                    NaN        P587K5587
# 439                          NaN                    NaN        P587K5587
# 440                          NaN                    NaN        P587K5587
# ...                          ...                    ...              ...
# 80541  Hypertrophy Tons And Aden             2014-12-29        CC9147587
# 81231    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81232    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81233    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81234    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
#
#            Encounter Status  Number of Records  Wait Time Min Days of Wk  \
# 169               Cancelled                  1             60     Monday
# 170               Cancelled                  1             78     Monday
# 438               Cancelled                  1              3     Monday
# 439               Cancelled                  1             13     Monday
# 440               Cancelled                  1             23     Monday
# ...                     ...                ...            ...        ...
# 80541   Day Surg Discharged                  1            124     Monday
# 81231  Inpatient Discharged                  1              3     Monday
# 81232  Inpatient Discharged                  1             16     Monday
# 81233  Inpatient Discharged                  1             33     Monday
# 81234  Inpatient Discharged                  1             79     Monday
#
#       Check-In Hour
# 169           06 AM
# 170           06 AM
# 438           06 AM
# 439           06 AM
# 440           06 AM
# ...             ...
# 80541         06 AM
# 81231         06 AM
# 81232         06 AM
# 81233         06 AM
# 81234         06 AM
#
# [354 rows x 15 columns]
#           Admit Source Admit Type        Appt Start Time  Care Score  \
# 169    Clinic Referral   Elective  2014-04-28 7:14:20 AM           5
# 170    Clinic Referral   Elective  2014-04-28 7:32:29 AM           3
# 438    Clinic Referral   Elective  2014-11-03 6:23:36 AM           3
# 439    Clinic Referral   Elective  2014-11-03 6:33:32 AM           2
# 440    Clinic Referral   Elective  2014-11-03 6:43:28 AM           3
# ...                ...        ...                    ...         ...
# 80541  Clinic Referral   Elective  2014-12-29 8:57:25 AM           2
# 81231  Clinic Referral   Elective  2014-12-29 6:49:10 AM           3
# 81232  Clinic Referral   Elective  2014-12-29 7:02:08 AM           2
# 81233  Clinic Referral   Elective  2014-12-29 7:19:42 AM           2
# 81234  Clinic Referral   Elective  2014-12-29 8:05:12 AM           2
#
#             Check-In Time      Clinic Name      Department  \
# 169   2014-04-28 06:14:00  Lakeview Center  Dental Surgery
# 170   2014-04-28 06:14:00  Lakeview Center  Dental Surgery
# 438   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# 439   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# 440   2014-11-03 06:20:00  Lakeview Center  Otolaryngology
# ...                   ...              ...             ...
# 80541 2014-12-29 06:53:00  Lakeview Center  Otolaryngology
# 81231 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81232 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81233 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
# 81234 2014-12-29 06:46:00  Lakeview Center  Otolaryngology
#
#                Diagnosis Primary Discharge Datetime new Encounter Number  \
# 169                          NaN                    NaN        1249P1587
# 170                          NaN                    NaN        1249P1587
# 438                          NaN                    NaN        P587K5587
# 439                          NaN                    NaN        P587K5587
# 440                          NaN                    NaN        P587K5587
# ...                          ...                    ...              ...
# 80541  Hypertrophy Tons And Aden             2014-12-29        CC9147587
# 81231    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81232    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81233    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
# 81234    Unc Behav Neo Oral/Phar             2015-01-06        5272C8587
#
#            Encounter Status  Number of Records  Wait Time Min Days of Wk  \
# 169               Cancelled                  1             60     Monday
# 170               Cancelled                  1             78     Monday
# 438               Cancelled                  1              3     Monday
# 439               Cancelled                  1             13     Monday
# 440               Cancelled                  1             23     Monday
# ...                     ...                ...            ...        ...
# 80541   Day Surg Discharged                  1            124     Monday
# 81231  Inpatient Discharged                  1              3     Monday
# 81232  Inpatient Discharged                  1             16     Monday
# 81233  Inpatient Discharged                  1             33     Monday
# 81234  Inpatient Discharged                  1             79     Monday
#
#       Check-In Hour
# 169           06 AM
# 170           06 AM
# 438           06 AM
# 439           06 AM
# 440           06 AM
# ...             ...
# 80541         06 AM
# 81231         06 AM
# 81232         06 AM
# 81233         06 AM
# 81234         06 AM
#
# [354 rows x 15 columns]
# None
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 1163   Emergency Room  Emergency   2014-01-05 9:03:37 PM           2
# ...               ...        ...                     ...         ...
# 80431  Emergency Room  Emergency   2014-12-28 8:12:19 PM           5
# 80432  Emergency Room  Emergency   2014-12-28 8:39:48 PM           4
# 80433  Emergency Room  Emergency   2014-12-28 8:32:52 PM           5
# 80495  Emergency Room  Emergency   2014-12-28 8:09:24 PM           2
# 80496  Emergency Room  Emergency  2014-12-28 10:14:48 PM           3
#
#             Check-In Time     Clinic Name Department        Diagnosis Primary  \
# 67    2014-02-16 19:50:00  Madison Center  Emergency                      NaN
# 83    2014-02-23 19:04:00  Madison Center  Emergency                      NaN
# 168   2014-04-27 19:15:00  Madison Center  Emergency                      NaN
# 292   2014-07-20 19:17:00  Madison Center  Emergency                      NaN
# 1163  2014-01-05 19:09:00  Madison Center  Emergency             Diarrhea Nos
# ...                   ...             ...        ...                      ...
# 80431 2014-12-28 19:33:00  Madison Center  Emergency                Fever Nos
# 80432 2014-12-28 19:52:00  Madison Center  Emergency  Head Injury Unspecified
# 80433 2014-12-28 19:55:00  Madison Center  Emergency       Sprain Of Foot Nos
# 80495 2014-12-28 19:37:00  Madison Center  Emergency             Diarrhea Nos
# 80496 2014-12-28 19:58:00  Madison Center  Emergency                 Wheezing
#
#       Discharge Datetime new Encounter Number Encounter Status  \
# 67                       NaN        179771587        Cancelled
# 83                       NaN        892P91587        Cancelled
# 168                      NaN        18C9PP587        Cancelled
# 292                      NaN        52K915587        Cancelled
# 1163              2014-01-05        P75K8C587    ED Discharged
# ...                      ...              ...              ...
# 80431             2014-12-28        1125K8587    ED Discharged
# 80432             2014-12-28        7125K8587    ED Discharged
# 80433             2014-12-28        8125K8587       Discharged
# 80495             2014-12-29        2125K8587       Discharged
# 80496             2014-12-29        9125K8587    ED Discharged
#
#        Number of Records  Wait Time Min Days of Wk Check-In Hour
# 67                     1            114     Sunday         07 PM
# 83                     1             29     Sunday         07 PM
# 168                    1            126     Sunday         07 PM
# 292                    1            134     Sunday         07 PM
# 1163                   1            114     Sunday         07 PM
# ...                  ...            ...        ...           ...
# 80431                  1             39     Sunday         07 PM
# 80432                  1             47     Sunday         07 PM
# 80433                  1             37     Sunday         07 PM
# 80495                  1             32     Sunday         07 PM
# 80496                  1            136     Sunday         07 PM
#
# [478 rows x 15 columns]
#
# None
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# None None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# None None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2024-09-01 None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2024-02-01 None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2024-01-01 None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2024-01-02 None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2014-01-02 None
# Madison Center
# ['Emergency Room', 'Clinic Referral', 'Physician Referral']
# 2014-01-02 2014-01-20
#          Admit Source Admit Type         Appt Start Time  Care Score  \
# 67     Emergency Room  Emergency   2014-02-16 9:44:03 PM           2
# 83     Emergency Room  Emergency   2014-02-23 7:33:23 PM           5
# 168    Emergency Room  Emergency   2014-04-27 9:21:26 PM           2
# 292    Emergency Room  Emergency   2014-07-20 9:31:30 PM           2
# 1163   Emergency Room  Emergency   2014-01-05 9:03:37 PM           2
# ...               ...        ...                     ...         ...
# 80431  Emergency Room  Emergency   2014-12-28 8:12:19 PM           5
# 168   2014-04-27 19:15:00  Madison Center  Emergency                      NaN
# 292   2014-07-20 19:17:00  Madison Center  Emergency                      NaN
# 1163  2014-01-05 19:09:00  Madison Center  Emergency             Diarrhea Nos
# ...                   ...             ...        ...                      ...
# 80431 2014-12-28 19:33:00  Madison Center  Emergency                Fever Nos
# 80432 2014-12-28 19:52:00  Madison Center  Emergency  Head Injury Unspecified
# 80433 2014-12-28 19:55:00  Madison Center  Emergency       Sprain Of Foot Nos
# 80495 2014-12-28 19:37:00  Madison Center  Emergency             Diarrhea Nos
# 80496 2014-12-28 19:58:00  Madison Center  Emergency                 Wheezing
#
#       Discharge Datetime new Encounter Number Encounter Status  \
# 67                       NaN        179771587        Cancelled
# 83                       NaN        892P91587        Cancelled
# 168                      NaN        18C9PP587        Cancelled
# 292                      NaN        52K915587        Cancelled
# 1163              2014-01-05        P75K8C587    ED Discharged
# ...                      ...              ...              ...
# 80431             2014-12-28        1125K8587    ED Discharged
# 80432             2014-12-28        7125K8587    ED Discharged
# 80433             2014-12-28        8125K8587       Discharged
# 80495             2014-12-29        2125K8587       Discharged
# 80496             2014-12-29        9125K8587    ED Discharged
#
#        Number of Records  Wait Time Min Days of Wk Check-In Hour
# 67                     1            114     Sunday         07 PM
# 83                     1             29     Sunday         07 PM
# 168                    1            126     Sunday         07 PM
# 292                    1            134     Sunday         07 PM
# 1163                   1            114     Sunday         07 PM
# ...                  ...            ...        ...           ...
# 80431                  1             39     Sunday         07 PM
# 80432                  1             47     Sunday         07 PM
# 80433                  1             37     Sunday         07 PM
# 80495                  1             32     Sunday         07 PM
# 80496                  1            136     Sunday         07 PM
#
# [478 rows x 15 columns]

# %% [markdown]
# # Caso de Uso:
#
# Una vez desarrollado el dashboard, se realizará un monitoreo continuo de la clínica **Madison Center** durante el periodo comprendido entre el 01/02/2014 y el 01/20/2014. Este análisis se centrará en las atenciones médicas recibidas en las especialidades de **Emergency Room, Clinic Referral y Physical Referral.**
#
# Como ejemplo representativo, se seleccionaron los valores de Sábado a las 07:00 am para observar el comportamiento de los pacientes en un día y hora específicos. En este intervalo, la clínica brindó atención a 34 pacientes.
#
# El dashboard no solo incluye un mapa de calor que permite visualizar la distribución temporal y espacial de las atenciones, sino también gráficos de tipo boxplot, los cuales facilitan la identificación del tiempo de espera y la calidad de la atención recibida por los pacientes.
#
# Para el grupo de los 34 pacientes mencionados, el tiempo promedio de espera en las especialidades de Emergency y Urgent osciló entre 60 y 80 minutos, mientras que en Elective fue de aproximadamente 30 minutos. En cuanto a la calificación de la atención (care score), las especialidades de Emergency y Urgent obtuvieron una media de 3 puntos, mientras que en Elective se alcanzó una calificación máxima de 4 puntos.

# %% [markdown]
# # Conclusiones
#
# Las diversas herramientas de graficación son muy útiles, como en este caso el filtrado y visualización de datos de forma interactiva da una mejor experiencia al usuario para darle a entender lo que busca en el conjunto de datos.
# En este caso plotly con dash muy buenos, rápidos y fáciles de comprender por su estructura de html con los callbacks que funciona como en javascript, proporciona una retroalimentación casi inmediata; depende de la programación de las funciones o su comportamiento pero, es muy bueno.
